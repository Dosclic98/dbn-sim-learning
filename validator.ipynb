# %%
import pysmile
import pysmile_license
from pathlib import Path
from pysmile.learning import DataSet, EM
import itertools
from expdef import Experiment, Analytic, Result
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fileName = "DBNfromAG_learned.xdsl"
dataFileName = "dbnLogs100.csv"
targetNode = "MMSserver1_unauthCmdMsg"
fixedNodes = ["historianServer_remoteShellAND", "MMSclient1_AND52", "MMSserver1_NodeAND23", "historianServer_NodeOR1"]
numSlices = 100

algoTypeExact = False

# %%
net = pysmile.Network()
net.read_file(fileName)
net.set_slice_count(numSlices)
if not algoTypeExact:
    # Set default inference algorithm and parameters
    net.set_bayesian_algorithm(pysmile.BayesianAlgorithmType.EPIS_SAMPLING)
    #pysmile.EPISParams.num_state_big
    # Print default EPIS algorithm parameters
    episParams = net.get_epis_params()
    episParams.propagation_length = 20  # Example modification
    net.set_epis_params(episParams)
    print("Propagation length: ", episParams.propagation_length)
    print("Num state small:", episParams.num_state_small)
    print("Num state medium:", episParams.num_state_medium)
    print("Num state big:", episParams.num_state_big)
else:
    net.set_bayesian_algorithm(pysmile.BayesianAlgorithmType.LAURITZEN)
# Out:
# Propagation length:  20
# Num state small: 5
# Num state medium: 8
# Num state big: 20

# %%
def plotDefinitions(net: pysmile.Network):
    nodeHandles = net.get_all_nodes()
    nodeIds = net.get_all_node_ids()
    for nodeHandle, nodeId in zip(nodeHandles, nodeIds):
        nodeDef = net.get_node_definition(nodeHandle)
        nodeOutcomes = net.get_outcome_ids(nodeHandle)
        print(f"Node ID: {nodeId}, Definition: {nodeDef}, Outcomes: {nodeOutcomes}")

# %%
from validator import Validator

validator: Validator = Validator(net, dataFileName, fixedNodes)
validator.addClassNode(targetNode)
validator.kFold(nFolds = 5)
# Out:
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 21, FP: 1, TN: 78, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 32, FP: 0, TN: 68, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 32, FP: 0, TN: 68, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 26, FP: 0, TN: 74, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 38, FP: 0, TN: 62, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 0, FP: 0, TN: 100, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 34, FP: 0, TN: 66, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 42, FP: 0, TN: 58, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 2, FP: 1, TN: 97, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 19, FP: 1, TN: 80, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 32, FP: 0, TN: 68, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 26, FP: 0, TN: 74, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 44, FP: 0, TN: 56, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 26, FP: 0, TN: 74, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 42, FP: 0, TN: 58, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 38, FP: 1, TN: 61, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 3, FP: 1, TN: 96, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 14, FP: 0, TN: 86, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 35, FP: 1, TN: 64, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 22, FP: 0, TN: 78, FN: 0
#     index DMZ_scanIP DMZ_scanIP_1 DMZ_scanIP_2 DMZ_scanIP_3 DMZ_scanIP_4  \
# 0      20          N            N            N            N            N
# 1      21          N            N            N            N            N
# 2      22          N            N            N            N            N
# 3      23          N            N            N            N            C
# 4      24          N            N            N            N            C
# 5      25          N            N            N            N            N
# 6      26          N            N            N            N            C
# 7      27          N            N            N            N            C
# 8      28          N            N            N            N            N
# 9      29          N            N            N            N            N
# 10     30          N            N            N            N            N
# 11     31          N            N            N            N            C
# 12     32          N            N            N            N            N
# 13     33          N            N            N            N            C
# 14     34          N            N            N            N            N
# 15     35          N            N            N            N            N
# 16     36          N            N            N            N            C
# 17     37          N            N            N            N            N
# 18     38          N            N            N            N            C
# 19     39          N            N            N            N            N
#
#    DMZ_scanIP_5 DMZ_scanIP_6 DMZ_scanIP_7 DMZ_scanIP_8  ...  \
# 0             C            C            C            C  ...
# 1             C            C            C            C  ...
# 2             C            C            C            C  ...
# 3             C            C            C            C  ...
# 4             C            C            C            C  ...
# 5             C            C            C            C  ...
# 6             C            C            C            C  ...
# 7             C            C            C            C  ...
# 8             C            C            C            C  ...
# 9             C            C            C            C  ...
# 10            C            C            C            C  ...
# 11            C            C            C            C  ...
# 12            C            C            C            C  ...
# 13            C            C            C            C  ...
# 14            C            C            C            C  ...
# 15            C            C            C            C  ...
# 16            C            C            C            C  ...
# 17            C            C            C            C  ...
# 18            C            C            C            C  ...
# 19            C            C            C            C  ...
#
#    workStation_compromise_140 workStation_compromise_141  \
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_142 workStation_compromise_143  \
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_144 workStation_compromise_145  \
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_146 workStation_compromise_147  \
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_148 workStation_compromise_149
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
# [20 rows x 3151 columns]
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 25, FP: 0, TN: 75, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 13, FP: 1, TN: 86, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 16, FP: 1, TN: 83, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 41, FP: 1, TN: 58, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 42, FP: 1, TN: 57, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 24, FP: 1, TN: 75, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 38, FP: 1, TN: 61, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 27, FP: 0, TN: 73, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 36, FP: 1, TN: 63, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 12, FP: 1, TN: 87, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 33, FP: 1, TN: 66, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 23, FP: 1, TN: 76, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 27, FP: 0, TN: 73, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 31, FP: 1, TN: 68, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 27, FP: 0, TN: 73, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 22, FP: 0, TN: 78, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 29, FP: 0, TN: 71, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 14, FP: 1, TN: 85, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 26, FP: 1, TN: 73, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 31, FP: 0, TN: 69, FN: 0
#     index DMZ_scanIP DMZ_scanIP_1 DMZ_scanIP_2 DMZ_scanIP_3 DMZ_scanIP_4  \
# 0      40          N            N            N            N            N
# 1      41          N            N            N            N            C
# 2      42          N            N            N            N            C
# 3      43          N            N            N            N            N
# 4      44          N            N            N            N            C
# 5      45          N            N            N            N            C
# 6      46          N            N            N            N            N
# 7      47          N            N            N            N            N
# 8      48          N            N            N            N            N
# 9      49          N            N            N            N            N
# 10     50          N            N            N            N            N
# 11     51          N            N            N            N            N
# 12     52          N            N            N            N            N
# 13     53          N            N            N            N            C
# 14     54          N            N            N            N            N
# 15     55          N            N            N            N            N
# 16     56          N            N            N            N            N
# 17     57          N            N            N            N            N
# 18     58          N            N            N            N            N
# 19     59          N            N            N            N            C
#
#    DMZ_scanIP_5 DMZ_scanIP_6 DMZ_scanIP_7 DMZ_scanIP_8  ...  \
# 0             C            C            C            C  ...
# 1             C            C            C            C  ...
# 2             C            C            C            C  ...
# 3             C            C            C            C  ...
# 4             C            C            C            C  ...
# 5             C            C            C            C  ...
# 6             C            C            C            C  ...
# 7             C            C            C            C  ...
# 8             C            C            C            C  ...
# 9             C            C            C            C  ...
# 10            C            C            C            C  ...
# 11            C            C            C            C  ...
# 12            C            C            C            C  ...
# 13            C            C            C            C  ...
# 14            C            C            C            C  ...
# 15            C            C            C            C  ...
# 16            C            C            C            C  ...
# 17            C            C            C            C  ...
# 18            C            C            C            C  ...
# 19            C            C            C            C  ...
#
#    workStation_compromise_140 workStation_compromise_141  \
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_142 workStation_compromise_143  \
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_144 workStation_compromise_145  \
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_146 workStation_compromise_147  \
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_148 workStation_compromise_149
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
# [20 rows x 3151 columns]
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 18, FP: 1, TN: 81, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 5, FP: 0, TN: 95, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 18, FP: 1, TN: 81, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 24, FP: 1, TN: 75, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 21, FP: 0, TN: 79, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 29, FP: 0, TN: 71, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 30, FP: 0, TN: 70, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 22, FP: 1, TN: 77, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 20, FP: 0, TN: 80, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 23, FP: 1, TN: 76, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 37, FP: 0, TN: 63, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 28, FP: 0, TN: 72, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 35, FP: 1, TN: 64, FN: 0
# ...
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_144 workStation_compromise_145  \
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_146 workStation_compromise_147  \
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
#    workStation_compromise_148 workStation_compromise_149
# 0                           C                          C
# 1                           C                          C
# 2                           C                          C
# 3                           C                          C
# 4                           C                          C
# 5                           C                          C
# 6                           C                          C
# 7                           C                          C
# 8                           C                          C
# 9                           C                          C
# 10                          C                          C
# 11                          C                          C
# 12                          C                          C
# 13                          C                          C
# 14                          C                          C
# 15                          C                          C
# 16                          C                          C
# 17                          C                          C
# 18                          C                          C
# 19                          C                          C
#
# [20 rows x 3151 columns]
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 39, FP: 1, TN: 60, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 29, FP: 1, TN: 70, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 19, FP: 0, TN: 81, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 12, FP: 0, TN: 88, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 30, FP: 1, TN: 69, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 23, FP: 0, TN: 77, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 15, FP: 0, TN: 85, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 3, FP: 1, TN: 96, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 30, FP: 0, TN: 70, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 2, FP: 1, TN: 97, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 18, FP: 1, TN: 81, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 31, FP: 0, TN: 69, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 39, FP: 1, TN: 60, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 26, FP: 0, TN: 74, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 36, FP: 1, TN: 63, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 2, FP: 0, TN: 98, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 25, FP: 1, TN: 74, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 27, FP: 0, TN: 73, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 19, FP: 0, TN: 81, FN: 0
# Confusion Matrix for node MMSserver1_unauthCmdMsg:
# TP: 12, FP: 0, TN: 88, FN: 0
# /mnt/c/Users/savarro/OneDrive - RSE S.P.A/Desktop/Materiale_Uni/Progetti/dbn-sim-learning/validator.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resDf = pd.concat([resDf, pd.DataFrame([resDict])], ignore_index=True)
