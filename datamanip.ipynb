# %%
import pandas as pd
from pandas import DataFrame 

df: DataFrame = pd.read_csv("dbnLogs.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.to_csv("dbnLogs.csv")
# Out:
#      DMZ_scanIP_0  DMZ_scanIP_1  DMZ_scanIP_2  DMZ_scanIP_3  DMZ_scanIP_4  \
# 0               2             2             2             2             2
# 1               1             2             2             2             2
# 2               2             2             2             2             2
# 3               1             2             2             2             2
# 4               2             2             2             2             2
# ..            ...           ...           ...           ...           ...
# 994             2             2             2             2             2
# 995             2             2             2             2             2
# 996             2             2             2             2             2
# 997             2             2             2             2             2
# 998             2             2             2             2             2
#
#      DMZ_scanIP_5  DMZ_scanIP_6  DMZ_scanIP_7  DMZ_scanIP_8  DMZ_scanIP_9  \
# ...
